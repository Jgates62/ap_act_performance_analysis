# %%
import pandas as pd

# %%
df_act_17 = pd.read_csv("../data/act_2017.csv")
df_act_17.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
df_sat_17 = pd.read_csv("../data/sat_2017.csv")
df_sat_17.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
df_act_18 = pd.read_csv("../data/act_2018.csv")
df_act_18.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
df_sat_18 = pd.read_csv("../data/sat_2018.csv")
df_sat_18.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
df_act_19 = pd.read_csv("../data/act_2019.csv")
df_act_19.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
df_sat_19 = pd.read_csv("../data/sat_2019.csv")
df_sat_19.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
df_act_19_ca = pd.read_csv("../data/act_2019_ca.csv")
df_act_19_ca #2018-2019
# Out:
#                CDS  CCode     CDCode      SCode RType  \
# 0     3.366993e+13   33.0  3366993.0   129882.0     S
# 1     1.964212e+13   19.0  1964212.0  1995596.0     S
# 2     1.563776e+13   15.0  1563776.0  1530377.0     S
# 3     4.369666e+13   43.0  4369666.0  4333795.0     S
# 4     1.964733e+13   19.0  1964733.0  1935121.0     S
# ...            ...    ...        ...        ...   ...
# 2305  5.810588e+13   58.0  5810587.0  5830112.0     S
# 2306  3.667959e+13   36.0  3667959.0  3638509.0     S
# 2307  3.667777e+13   36.0  3667777.0  3638616.0     S
# 2308  3.667850e+13   36.0  3667850.0  3630530.0     S
# 2309           NaN    NaN        NaN        NaN   NaN
#
#                                        SName                            DName  \
# 0            21st Century Learning Institute                 Beaumont Unified
# 1                ABC Secondary (Alternative)                      ABC Unified
# 2                Abraham Lincoln Alternative            Southern Kern Unified
# ...

# %%
df_sat_19_ca = pd.read_csv("../data/sat_2019_ca.csv")
df_sat_19_ca #2018-2019
# Out:
#                CDS  CCode     CDCode      SCode RType  \
# 0     6.615981e+12    6.0   661598.0   630046.0     S
# 1     6.616061e+12    6.0   661606.0   634758.0     S
# 2     1.964733e+13   19.0  1964733.0  1930924.0     S
# 3     1.964733e+13   19.0  1964733.0  1931476.0     S
# 4     1.964733e+13   19.0  1964733.0  1931856.0     S
# ...            ...    ...        ...        ...   ...
# 2575  5.772678e+13   57.0  5772678.0        0.0     D
# 2576  7.000000e+12    7.0   700000.0        0.0     C
# 2577  1.700000e+13   17.0  1700000.0        0.0     C
# 2578  3.800000e+13   38.0  3800000.0        0.0     C
# 2579           NaN    NaN        NaN        NaN   NaN
#
#                         SName                DName          CName  Enroll12  \
# 0     Colusa Alternative Home       Colusa Unified         Colusa      18.0
# 1             Maxwell Sr High      Maxwell Unified         Colusa      29.0
# 2         Belmont Senior High  Los Angeles Unified    Los Angeles     206.0
# ...

# %%
df_sat_19_maj = pd.read_csv("../data/sat_2019_by_intended_college_major.csv")
df_sat_19_maj.head()
# Out:
#                                 IntendedCollegeMajor TestTakers Percent  \
# 0  Agriculture, AgricultureOperations, and Relate...     24,913      1%
# 1                  Architecture and Related Services     28,988      2%
# 2         Area, Ethnic, Cultural, and Gender Studies      2,629      0%
# 3                 Biological and Biomedical Sciences    155,834      8%
# 4  Business, Management, Marketing, and Related S...    221,523     12%
#
#    Total  ReadingWriting  Math
# 0    977             496   481
# 1   1047             520   527
# 2   1040             536   504
# 3   1139             572   566
# 4   1072             534   537

# %%
df_sat_act_college = pd.read_csv("../data/sat_act_by_college.csv")
df_sat_act_college.head(10)
# Out:
#                                   School Test Optional?  \
# 0                    Stanford University            Yes
# 1                        Harvard College            Yes
# 2                   Princeton University            Yes
# 3                    Columbia University            Yes
# 4                        Yale University            Yes
# 5     California Institute of Technology       Yes (TB)
# 6  Massachusetts Institute of Technology            Yes
# 7                       Brown University            Yes
# 8                  University of Chicago            Yes
# 9                         Pomona College            Yes
#
#   Applies to Class Year(s)                                     Policy Details  \
# 0                     2021  Stanford has adopted a one-year test optional ...
# 1                     2021  Harvard has adopted a one-year test optional p...
# 2                     2021  Princeton has adopted a one-year test optional...
# ...

# %%
df_sat_act_college.shape
# Out:
# (416, 8)
